# %% [markdown]
# # Weather Retrieval
#
# <br>
#
# ### Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import time

from DarkSky import Wrapper 
from windrose import WindroseAxes

from ipypb import track

# %% [markdown]
# <br>
#
# ### Helper Functions

# %%
def hide_spines(ax, positions=['top', 'right']):
    """
    Pass a matplotlib axis and list of positions with spines to be removed
    
    args:
        ax:          Matplotlib axis object
        positions:   Python list e.g. ['top', 'bottom']
    """
    assert isinstance(positions, list), 'Position must be passed as a list '
    
    for position in positions:
        ax.spines[position].set_visible(False)

# %% [markdown]
# <br>
#
# ### Making a Request
#
# You will have to add your own API key, they can be requested from <a href="https://darksky.net/dev">here</a>.

# %%
API_key = ''

dt = pd.to_datetime('2018-01-01')
latitude = '51.516554'
longitude = '-0.218503'

darksky = Wrapper(API_key)
df = darksky.lat_lon_dt_2_df(latitude, longitude, time=dt)

df.head()
# Out:
#                  time        summary                 icon  precipIntensity  \
# 0 2018-01-01 00:00:00  Partly Cloudy  partly-cloudy-night              0.0
# 1 2018-01-01 01:00:00  Partly Cloudy  partly-cloudy-night              0.0
# 2 2018-01-01 02:00:00          Clear          clear-night              0.0
# 3 2018-01-01 03:00:00          Clear          clear-night              0.0
# 4 2018-01-01 04:00:00  Mostly Cloudy  partly-cloudy-night              0.0
#
#    precipProbability  temperature  apparentTemperature  dewPoint  humidity  \
# 0                0.0        44.81                39.64     38.93      0.80
# 1                0.0        44.25                39.99     38.30      0.79
# 2                0.0        43.35                39.35     37.61      0.80
# 3                0.0        42.96                38.66     37.01      0.79
# 4                0.0        42.71                38.73     37.05      0.80
#
#    pressure  windSpeed  windGust  windBearing  cloudCover  uvIndex  \
# 0     997.3       9.90     16.61          251        0.47        0
# 1     998.3       7.53     12.07          259        0.31        0
# 2     999.5       6.69     11.44          250        0.19        0
# 3     999.5       7.07     13.10          242        0.09        0
# 4     999.6       6.43     13.36          232        0.70        0
#
#    visibility precipType
# 0       6.216        NaN
# 1       6.216        NaN
# 2       6.216        NaN
# 3       6.216        NaN
# 4       6.216        NaN

# %% [markdown]
# <br>
#
# ### Retrieving Data Over a Date Range
#
# Before making the requests we have to create the date range

# %%
start_date = '2018-09-20 11:00:00'
end_date = '2020-01-13 00:00:00'

dt_rng = pd.date_range(start_date, end_date, freq='D')

dt_rng
# Out:
# DatetimeIndex(['2018-09-20 11:00:00', '2018-09-21 11:00:00',
#                '2018-09-22 11:00:00', '2018-09-23 11:00:00',
#                '2018-09-24 11:00:00', '2018-09-25 11:00:00',
#                '2018-09-26 11:00:00', '2018-09-27 11:00:00',
#                '2018-09-28 11:00:00', '2018-09-29 11:00:00',
#                ...
#                '2020-01-03 11:00:00', '2020-01-04 11:00:00',
#                '2020-01-05 11:00:00', '2020-01-06 11:00:00',
#                '2020-01-07 11:00:00', '2020-01-08 11:00:00',
#                '2020-01-09 11:00:00', '2020-01-10 11:00:00',
#                '2020-01-11 11:00:00', '2020-01-12 11:00:00'],
#               dtype='datetime64[ns]', length=480, freq='D')

# %% [markdown]
# <br>
#
# We're now ready to iterate over the dates and combine them within a single dataframe

# %%
df = pd.DataFrame()

for dt in track(dt_rng):
    df_dt = darksky.lat_lon_dt_2_df(latitude, longitude, time=dt)
    df = df.append(df_dt, sort=False)
    
    time.sleep(1) # Significantly reduces the number of times the request is rejected
    
df.head(2)
# Out:
#  [████████████████████████████████████████████████████████████] 480/480 [08:59<00:01, 1.12s/it]
#                  time   summary    icon  precipIntensity  precipProbability  \
# 0 2018-09-20 00:00:00  Overcast  cloudy           0.0011               0.06
# 1 2018-09-20 01:00:00  Overcast  cloudy           0.0010               0.06
#
#   precipType  temperature  apparentTemperature  dewPoint  humidity  pressure  \
# 0       rain        64.86                64.86     58.90      0.81    1014.5
# 1       rain        64.31                64.31     58.74      0.82    1014.5
#
#    windSpeed  windGust  windBearing  cloudCover  uvIndex  visibility  ozone  \
# 0      12.42     24.87          229        0.93        0        10.0  291.0
# 1      11.56     22.86          214        0.90        0        10.0  292.2
#
#    precipAccumulation
# 0                 NaN
# 1                 NaN

# %%
df.tail(2)
# Out:
#                      time summary         icon  precipIntensity  \
# 11519 2020-01-12 22:00:00   Clear  clear-night              0.0
# 11520 2020-01-12 23:00:00   Clear  clear-night              0.0
#
#        precipProbability precipType  temperature  apparentTemperature  \
# 11519                0.0        NaN        45.17                40.85
# 11520                0.0        NaN        44.85                40.48
#
#        dewPoint  humidity  pressure  windSpeed  windGust  windBearing  \
# 11519     39.87      0.82    1020.3       8.09     21.64          224
# 11520     39.42      0.81    1020.6       8.03     23.02          223
#
#        cloudCover  uvIndex  visibility  ozone  precipAccumulation
# 11519        0.05        0        10.0  347.7                 NaN
# 11520        0.19        0        10.0  356.5                 NaN

# %% [markdown]
# <br>
#
# We'll save the dataframe before moving on to the EDA

# %%
save_df = False

if save_df == True:
    df.to_csv('data/darksky_weather.csv', index=False)

# %% [markdown]
# <br>
#
# ### Exploratory Data Analysis
#
# We start by reading in the data

# %%
read_df = True

if read_df == True:
    df = pd.read_csv('data/darksky_weather.csv')
    df['time'] = pd.to_datetime(df['time'])
    
df_focus = df.set_index('time')[['temperature', 'windBearing', 'windSpeed', 'ozone', 'precipIntensity']]

df_focus.head()
# Out:
#                      temperature  windBearing  windSpeed  ozone  \
# time
# 2018-09-20 00:00:00        64.86          229      12.42  291.0
# 2018-09-20 01:00:00        64.31          214      11.56  292.2
# 2018-09-20 02:00:00        64.39          214      12.20  292.2
# 2018-09-20 03:00:00        64.62          216      13.37  292.0
# 2018-09-20 04:00:00        64.86          217      14.19  292.0
#
#                      precipIntensity
# time
# 2018-09-20 00:00:00           0.0011
# 2018-09-20 01:00:00           0.0010
# 2018-09-20 02:00:00           0.0010
# 2018-09-20 03:00:00           0.0010
# 2018-09-20 04:00:00           0.0010

# %% [markdown]
# <br>
#
# We'll now look at how temperature varies over the date range

# %%
rolling_days = 28

s_rolling_temp = (df_focus
                  ['temperature']
                  .rolling(f'{rolling_days}D')
                  .mean()
                  .shift(-rolling_days//2, freq='D')
                 )

## Plotting
fig, ax = plt.subplots(dpi=250)

df_focus['temperature'].plot(ax=ax, color='k', linewidth=0.25, alpha=0.25)
s_rolling_temp.plot(ax=ax, color='red', linewidth=1)

ax.set_xlabel('')
ax.set_ylabel('Temperature (degC)')
ax.set_xlim(df_focus.index[0], df_focus.index[-1])

hide_spines(ax)

# %% [markdown]
# <br>
#
# We can also create a windrose for the site

# %%
fig = plt.figure(dpi=250)
ax = WindroseAxes.from_ax(fig=fig)

ax.bar(df_focus['windBearing'], df_focus['windSpeed'], normed=True, opening=0.8, edgecolor='white')

ax.legend(frameon=False, bbox_to_anchor=(0.95, 0.95), 
          title='Wind Speeds', prop={'size': 6}, title_fontsize=8)

# %% [markdown]
# <br>
#
# For ozone we'll take a similar approach to temperature

# %%
rolling_days = 28

s_rolling_ozone = (df_focus
                  ['ozone']
                  .rolling(f'{rolling_days}D')
                  .mean()
                  .shift(-rolling_days//2, freq='D')
                 )

## Plotting
fig, ax = plt.subplots(dpi=250)

df_focus['ozone'].plot(ax=ax, color='k', linewidth=0.75, alpha=0.25)
s_rolling_ozone.plot(ax=ax, color='red', linewidth=1)

ax.set_xlabel('')
ax.set_ylabel('Ozone (DU)')
ax.set_xlim(df_focus.index[0], df_focus.index[-1])

hide_spines(ax)

# %% [markdown]
# <br>
#
# Finally we'll look at how rainfall changes on a monthly basis, the values seem very low for England.

# %%
s_monthly_precip = (df_focus
                    ['precipIntensity']
                    .resample('M')
                    .sum()
                    .shift(15, 'D')
                   )

dates = s_monthly_precip.index
precip_mm = s_monthly_precip.values

dt_idxs = list(range(dates.shape[0]))
labels = [f'{x[0]}\n{x[1]}' for x in list(zip(dates.month_name(), dates.year.astype(str)))]

## Plotting
fig, ax = plt.subplots(dpi=250)

ax.bar(dt_idxs, precip_mm, color='deepskyblue')

ax.set_xticks(dt_idxs[::3])
ax.set_xticklabels(labels[::3])
ax.set_ylabel('Total Precipitation (mm)')

hide_spines(ax)
